# %%
# setting the working directory
import os
os.chdir("C:/Users/User/Desktop/SCUOLA/UNI/2.Magistrale/TESI/Causal_Inference_for_Multivariate_Time_Series/Code/Python code/real world data/Hybrid file")

# %%
from Custom_Dataset_Loader import CustomDatasetLoader as cdl

loader = cdl(
    file_path="data/Antivirus_Activity/preprocessed_1.csv",    # Path to your dataset file
    sep=",",                         # Separator used in the file, adjust as needed
    header=0,                        # Row number to use as column names
    ground_truth_col=None,            # Name of the ground truth column, if present
    drop_missing=True,
    drop_columns=0      # List of columns to drop from the dataset
)

# Load the dataset eliminating timestamp column using Custom_Data_Loader
daata = loader.load_custom_dataset()

# Analyze the structure of the loaded dataset
loader.analyze_data_structure()
# Out:
# Dataset: preprocessed_1
# Observations DataFrame Head:
#    memory_usage_Portal  cpu_usage_Portal  Physical_Memory_prct_used_Portal  \
# 0                  1.2               0.0                              52.0
# 1                  1.2               0.0                              52.0
# 2                  1.2               0.0                              51.0
# 3                  1.2               0.0                              51.0
# 4                  1.2               0.0                              52.0
#
#    cpu_prct_used_Portal  0_C_read_Portal  memory_usage_VDI  cpu_usage_VDI  \
# 0                  1.75              0.0               2.3            0.0
# 1                  2.00              0.0               2.3            0.0
# 2                  2.00              0.0               2.3            0.0
# 3                  2.25              0.0               2.3            0.0
# 4                  1.75              0.0               2.3            0.0
#
#    Physical_Memory_prct_used_VDI  cpu_prct_used_VDI  0_C_read_VDI  \
# 0                           62.0                3.5           0.0
# 1                           62.0                3.5           0.0
# 2                           62.0                3.0           0.0
# 3                           62.0                3.0           0.0
# 4                           62.0                3.0           0.0
#
#    Chargement_portail  Chargement_IE  Default_Transaction
# 0               1.712         16.958                58.91
# 1               1.712         16.958                58.91
# 2               1.712         16.958                58.91
# 3               1.712         16.958                58.91
# 4               1.712         16.958                58.91
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   memory_usage_Portal               1320 non-null   float64
#  1   cpu_usage_Portal                  1320 non-null   float64
#  2   Physical_Memory_prct_used_Portal  1320 non-null   float64
#  3   cpu_prct_used_Portal              1320 non-null   float64
#  4   0_C_read_Portal                   1320 non-null   float64
#  5   memory_usage_VDI                  1320 non-null   float64
#  6   cpu_usage_VDI                     1320 non-null   float64
#  7   Physical_Memory_prct_used_VDI     1320 non-null   float64
#  8   cpu_prct_used_VDI                 1320 non-null   float64
#  9   0_C_read_VDI                      1320 non-null   float64
#  10  Chargement_portail                1320 non-null   float64
#  11  Chargement_IE                     1320 non-null   float64
#  12  Default_Transaction               1320 non-null   float64
# dtypes: float64(13)
# memory usage: 134.2 KB
# None
#
# Ground Truth:
# No ground truth provided.
#
# --------------------------------------------------
#
# Dataset: preprocessed_1
# Observations DataFrame Head:
#    memory_usage_Portal  cpu_usage_Portal  Physical_Memory_prct_used_Portal  \
# 0                  1.2               0.0                              52.0
# 1                  1.2               0.0                              52.0
# 2                  1.2               0.0                              51.0
# 3                  1.2               0.0                              51.0
# 4                  1.2               0.0                              52.0
#
#    cpu_prct_used_Portal  0_C_read_Portal  memory_usage_VDI  cpu_usage_VDI  \
# 0                  1.75              0.0               2.3            0.0
# 1                  2.00              0.0               2.3            0.0
# 2                  2.00              0.0               2.3            0.0
# 3                  2.25              0.0               2.3            0.0
# 4                  1.75              0.0               2.3            0.0
#
#    Physical_Memory_prct_used_VDI  cpu_prct_used_VDI  0_C_read_VDI  \
# 0                           62.0                3.5           0.0
# 1                           62.0                3.5           0.0
# 2                           62.0                3.0           0.0
# 3                           62.0                3.0           0.0
# 4                           62.0                3.0           0.0
#
#    Chargement_portail  Chargement_IE  Default_Transaction
# 0               1.712         16.958                58.91
# 1               1.712         16.958                58.91
# 2               1.712         16.958                58.91
# 3               1.712         16.958                58.91
# 4               1.712         16.958                58.91
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   memory_usage_Portal               1320 non-null   float64
#  1   cpu_usage_Portal                  1320 non-null   float64
#  2   Physical_Memory_prct_used_Portal  1320 non-null   float64
#  3   cpu_prct_used_Portal              1320 non-null   float64
#  4   0_C_read_Portal                   1320 non-null   float64
#  5   memory_usage_VDI                  1320 non-null   float64
#  6   cpu_usage_VDI                     1320 non-null   float64
#  7   Physical_Memory_prct_used_VDI     1320 non-null   float64
#  8   cpu_prct_used_VDI                 1320 non-null   float64
#  9   0_C_read_VDI                      1320 non-null   float64
#  10  Chargement_portail                1320 non-null   float64
#  11  Chargement_IE                     1320 non-null   float64
#  12  Default_Transaction               1320 non-null   float64
# dtypes: float64(13)
# memory usage: 134.2 KB
# None
#
# Ground Truth:
# No ground truth provided.
#
# --------------------------------------------------

# %%
# enumerated list of elements in data 
for i, elem in enumerate(daata):
    print(i,elem)
# Out:
# 0 preprocessed_1
